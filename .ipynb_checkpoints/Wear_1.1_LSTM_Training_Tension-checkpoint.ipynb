# %% [markdown]
# Importing Library

# %%
import os, sklearn, math
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from joblib import dump, load

tf.random.set_seed(42)

# %% [markdown]
# Loading experimental data set

# %%
data = '230630_data' # Experimental data name
dataname = data+'Tension'+'_0630_2' # Ouput name
filename = 'myLearningData/'+data+'.csv' # Setting route of experimental data
SD = pd.read_csv(filename) # Loading experimental data to dataframe by pandas
SD=SD.iloc[:,:5] # Pandas code: (:)All row (5) five columns
SensorData = SD # Rename

# %%
SD
# Out:
#        Time  Displacement  Tension  Resistance       cycle
# 0     24.02          0.00     -3.1        8.46  Stretching
# 1     24.03          0.00     -3.1        8.46  Stretching
# 2     24.04          0.00     -3.0        8.46  Stretching
# 3     24.05          0.01     -3.1        8.39  Stretching
# 4     24.06          0.03     -2.8        8.39  Stretching
# ...     ...           ...      ...         ...         ...
# 3878  71.95          0.00     -3.2        8.71    Relaxing
# 3879  71.97          0.00     -3.4        8.71    Relaxing
# 3880  71.98          0.00     -3.7        8.65    Relaxing
# 3881  71.99          0.00     -3.5        8.71    Relaxing
# 3882  72.00          0.00     -3.2        8.71    Relaxing
#
# [3883 rows x 5 columns]

# %%
SD.describe()
# Out:
#               Time  Displacement      Tension   Resistance
# count  3883.000000   3883.000000  3883.000000  3883.000000
# mean     48.008653      6.006531    22.930157    22.713667
# std      13.858605      3.606321    14.749852     8.412671
# min      24.020000     -0.010000    -4.900000     8.390000
# 25%      36.020000      2.860000    11.100000    15.040000
# 50%      48.010000      6.030000    22.900000    23.710000
# 75%      60.010000      9.140000    34.900000    30.430000
# max      72.000000     12.010000    50.200000    35.470000

# %%
X = SD.iloc[:,[0,1]]
X
# Out:
#        Time  Displacement
# 0     24.02          0.00
# 1     24.03          0.00
# 2     24.04          0.00
# 3     24.05          0.01
# 4     24.06          0.03
# ...     ...           ...
# 3878  71.95          0.00
# 3879  71.97          0.00
# 3880  71.98          0.00
# 3881  71.99          0.00
# 3882  72.00          0.00
#
# [3883 rows x 2 columns]

# %%
SD['Resistance'] = (SD['Resistance']-SD['Resistance'].mean())/(SD['Resistance'].max()-SD['Resistance'].min())*2
SD['Displacement'] = (SD['Displacement']-SD['Displacement'].mean())/(SD['Displacement'].max()-SD['Displacement'].min())*2
SD['Tension'] = (SD['Tension']-SD['Tension'].mean())/(SD['Tension'].max()-SD['Tension'].min())*2

# %%
X = SD.iloc[:,[0,1]]
X['index'] = X.index+1
X = X[['index','Time','Displacement']]
y = SD.iloc[:,[2]]
#y['index'] = y.index+1
#y = y[['index','Time','Distance']]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7812\4070815710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['index'] = X.index+1

# %%
X.sample(5)
# Out:
#       index   Time  Displacement
# 2634   2635  56.58      0.481442
# 1438   1439  41.79      0.007233
# 1761   1762  45.78     -0.689939
# 1014   1015  36.55      0.910727
# 92       93  25.15     -0.806411

# %%
y.sample(5)
# Out:
#        Tension
# 1699 -0.589116
# 3813 -0.923055
# 2738  0.692190
# 1670 -0.523781
# 757   0.655893

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size = 0.01, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.20, random_state=42)

# %%
X_sum = len(X_train)+len(X_valid)+len(X_test)
X_train_per = int(len(X_train)/X_sum*100)
X_valid_per = int(len(X_valid)/X_sum*100)
X_test_per = int(len(X_test)/X_sum*100)

print('X_train: ',len(X_train),'ea',X_train_per,'%   ', 
      'X_valid: ',len(X_valid),'ea',X_valid_per,'%   ',
      'X_test: ',len(X_test),'ea',X_test_per,'%',)
# Out:
# X_train:  3075 ea 79 %    X_valid:  769 ea 19 %    X_test:  39 ea 1 %

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_valid = X_valid.reshape((X_valid.shape[0], 1, X_valid.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %%
X_train.shape
# Out:
# (3075, 1, 3)

# %%
import pickle
from joblib import dump, load

file_name = 'myScaler/'+dataname+'_LSTM'+'_SS.pkl'
dump(scaler, file_name)
# Out:
# ['myScaler/230630_dataTension_0630_2_LSTM_SS.pkl']

# %%
from tensorflow import keras
model = keras.models.Sequential([
    keras.layers.LSTM(16, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    keras.layers.LSTM(16, return_sequences=True),
    keras.layers.LSTM(16),
    keras.layers.Dense(1)
])

model.compile(loss="mean_squared_error", optimizer=keras.optimizers.RMSprop(learning_rate=1e-3, rho = 0.9))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 16)             1280
#
#  lstm_1 (LSTM)               (None, 1, 16)             2112
#
#  lstm_2 (LSTM)               (None, 16)                2112
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 5,521
# Trainable params: 5,521
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Callback (best, early stopping, tensorboard)

# %%
import os 
#root_logdir = os.path.join(os.curdir, 'mylog/'+data)
root_logdir = os.path.join(os.curdir, 'mylog/'+'230703')

def get_run_logdir():
    import time
    run_id= time.strftime("%m%d_%Hh%Mm%Ss"+dataname)
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()

# %%
K = keras.backend
class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, rate)

# %%
dataname
# Out:
# '230630_dataTension_0630_2'

# %%
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 10, restore_best_weights = True)
n_epochs = 300
batch_size = 1
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs, max_rate=0.05)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle,early_stopping_cb,tensorboard_cb])
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:5]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/300
#  1/97 [..............................] - ETA: 8:47 - loss: 0.2129WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_train_batch_end` time: 0.0479s). Check your callbacks.
# 97/97 [==============================] - 7s 19ms/step - loss: 0.0569 - val_loss: 0.0239
# Epoch 2/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0191 - val_loss: 0.0399
# Epoch 3/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0182 - val_loss: 0.0303
# Epoch 4/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0153 - val_loss: 0.0261
# Epoch 5/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0075 - val_loss: 0.0068
# Epoch 6/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0040 - val_loss: 0.0081
# Epoch 7/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0144
# Epoch 8/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0030 - val_loss: 0.0086
# Epoch 9/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0086
# Epoch 10/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 11/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 12/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 13/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 14/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 15/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0021 - val_loss: 9.2194e-04
# Epoch 16/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 17/300
# 97/97 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0060
# Epoch 18/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0154
# Epoch 19/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0055
# Epoch 20/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 21/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 22/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 23/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 24/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0017 - val_loss: 8.7631e-04
# Epoch 25/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 26/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 27/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0016 - val_loss: 0.0045
# Epoch 28/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 29/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 7.0368e-04
# Epoch 30/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 31/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 32/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 33/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0091
# Epoch 34/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 35/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 36/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 37/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 38/300
# 97/97 [==============================] - 1s 7ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 39/300
# 97/97 [==============================] - 1s 6ms/step - loss: 0.0013 - val_loss: 0.0039
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0010
# 1/1 [==============================] - 1s 1s/step

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./mylog/230630 --port=6006
# Out:
#       <iframe id="tensorboard-frame-a7946bd25cd83514" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a7946bd25cd83514");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.save('H:/Jupyter_project/wearableActuator/myModel/'+dataname+'_LSTM'+'.h5')

# %%
model = tf.keras.models.load_model('myModel/'+dataname+'_LSTM'+'.h5')
scaler = load(file_name)
valid_predictions = model.predict(X_valid)
# Out:
# 25/25 [==============================] - 2s 2ms/step

# %%
X_valid
# Out:
# array([[[ 1.23422514,  1.23439576,  0.19124791]],
#
#        [[-0.97306533, -0.97324874,  1.39702648]],
#
#        [[ 1.09436433,  1.09442355,  0.74285696]],
#
#        ...,
#
#        [[ 0.81912543,  0.81883061,  1.59937553]],
#
#        [[-1.16133949, -1.16108709,  0.6513841 ]],
#
#        [[-0.92644506, -0.92610785,  1.5827441 ]]])

# %%
valid_predictions
# Out:
# array([[-8.62051174e-02],
#        [ 8.35222900e-01],
#        [ 1.98911548e-01],
#        [ 9.39132214e-01],
#        [-1.73497632e-01],
#        [-5.31677902e-01],
#        [ 1.44158766e-01],
#        [ 1.52723998e-01],
#        [-6.87769115e-01],
#        [ 6.14678487e-02],
#        [-8.69574130e-01],
#        [-4.19124782e-01],
#        [ 9.48007762e-01],
#        [-4.85671341e-01],
#        [-4.53249872e-01],
#        [ 4.37474042e-01],
#        [ 5.08400142e-01],
#        [ 8.11083138e-01],
#        [ 9.55573499e-01],
#        [ 4.29038644e-01],
#        [ 2.04784870e-01],
#        [-7.56746292e-01],
#        [-1.56632140e-01],
#        [-8.74631464e-01],
#        [ 7.20276773e-01],
#        [ 5.98372042e-01],
#        [-1.36738881e-01],
#        [-9.26312864e-01],
#        [ 1.46526709e-01],
#        [ 4.44117725e-01],
#        [-4.21777427e-01],
#        [-8.60622823e-01],
#        [-6.63690329e-01],
#        [-1.91225395e-01],
#        [ 4.68602508e-01],
#        [-2.32200578e-01],
#        [-2.34206207e-03],
#        [-3.03179234e-01],
#        [-7.01040685e-01],
#        [ 3.08668554e-01],
#        [-1.60425007e-01],
#        [ 1.09855846e-01],
#        [ 3.97517353e-01],
#        [ 1.56398967e-01],
#        [-7.37852693e-01],
#        [-6.73294008e-01],
#        [-8.37934017e-01],
#        [-4.90724385e-01],
#        [ 6.86017752e-01],
#        [-9.39364016e-01],
#        [-3.42607915e-01],
#        [ 6.27279580e-01],
#        [ 6.29858911e-01],
#        [-7.51115739e-01],
#        [-6.12358630e-01],
#        [-5.94181776e-01],
#        [-8.64720881e-01],
#        [-3.03528041e-01],
#        [-1.65947407e-01],
#        [-6.61804199e-01],
#        [-2.94568781e-02],
#        [ 7.27075815e-01],
#        [-4.10688758e-01],
#        [ 2.72699326e-01],
#        [-7.83952400e-02],
#        [ 7.45136678e-01],
#        [-1.21450551e-01],
#        [-8.67043674e-01],
#        [ 9.34275270e-01],
#        [-8.31600726e-01],
#        [ 3.23461771e-01],
#        [ 5.54062277e-02],
#        [-5.52380204e-01],
#        [ 3.12135130e-01],
#        [-1.86356798e-01],
#        [ 9.50139105e-01],
#        [-5.88537097e-01],
#        [ 1.38102934e-01],
#        [-2.04596203e-02],
#        [ 4.72766221e-01],
#        [ 3.22605491e-01],
#        [-8.27187479e-01],
#        [-3.77896249e-01],
#        [ 3.64623398e-01],
#        [-5.95010042e-01],
#        [-8.96664411e-02],
#        [-3.99961680e-01],
#        [-1.45549759e-01],
#        [ 4.32257801e-02],
#        [-8.25461686e-01],
#        [-2.09161356e-01],
#        [-7.89697826e-01],
#        [-4.77812231e-01],
#        [ 3.23259532e-01],
#        [-1.00447977e+00],
#        [ 4.34178740e-01],
#        [ 6.40639365e-02],
#        [ 9.04633522e-01],
#        [-5.78774571e-01],
#        [-4.50820327e-01],
#        [ 2.52920151e-01],
#        [ 6.80033743e-01],
#        [ 4.73095298e-01],
#        [ 7.23520935e-01],
#        [-1.40366986e-01],
#        [-9.87733781e-01],
#        [-8.41759741e-01],
#        [-5.76750159e-01],
#        [-2.69739568e-01],
#        [-1.00588143e+00],
#        [ 4.02906165e-02],
#        [-3.94454956e-01],
#        [-1.25834957e-01],
#        [-2.63783336e-01],
#        [ 5.17413616e-01],
#        [-3.25675577e-01],
#        [ 4.86022174e-01],
#        [-8.86831224e-01],
#        [ 7.47029543e-01],
#        [-9.19405103e-01],
#        [ 2.84298152e-01],
#        [-9.33767915e-01],
#        [ 4.45237517e-01],
#        [-1.74979687e-01],
#        [-8.52502286e-01],
#        [-2.50512123e-01],
#        [ 5.31681657e-01],
#        [-8.44615281e-01],
#        [-4.04018700e-01],
#        [-3.66347790e-01],
#        [-7.81768262e-01],
#        [-3.45327437e-01],
#        [-8.75302136e-01],
#        [-7.50981569e-01],
#        [ 6.66261077e-01],
#        [-8.80369067e-01],
#        [-2.91489482e-01],
#        [ 9.22543824e-01],
#        [-6.26727268e-02],
#        [ 8.86695921e-01],
#        [ 6.41941845e-01],
#        [-3.78363073e-01],
#        [-5.64821884e-02],
#        [ 3.06013525e-01],
#        [-6.18378520e-01],
#        [-8.71287212e-02],
#        [-9.99363959e-01],
#        [-4.32716131e-01],
#        [-5.70473135e-01],
#        [ 2.12676451e-01],
#        [ 3.09864640e-01],
#        [-5.99531293e-01],
#        [-3.47648799e-01],
#        [-1.87524736e-01],
#        [ 1.94028303e-01],
#        [ 8.30059469e-01],
#        [ 8.10055137e-01],
#        [ 4.76216793e-01],
#        [-9.03274179e-01],
#        [-2.43819430e-01],
#        [-6.52926087e-01],
#        [ 8.31736743e-01],
#        [ 4.83435601e-01],
#        [ 7.55792916e-01],
#        [-5.12074158e-02],
#        [ 4.18618023e-01],
#        [-7.25431859e-01],
#        [-5.08310854e-01],
#        [ 3.32056791e-01],
#        [-6.25507832e-02],
#        [-5.55990338e-01],
#        [-3.90131921e-01],
#        [ 8.66916358e-01],
#        [ 3.21202159e-01],
#        [ 4.00387421e-02],
#        [ 5.85991383e-01],
#        [-8.50147232e-02],
#        [-6.01572454e-01],
#        [ 8.78233671e-01],
#        [-6.37554944e-01],
#        [-7.31119737e-02],
#        [ 1.43589973e-01],
#        [ 6.81325316e-01],
#        [-8.38853955e-01],
#        [-5.48609138e-01],
#        [ 2.68200040e-01],
#        [-3.90423477e-01],
#        [-8.97125244e-01],
#        [-2.53151000e-01],
#        [ 7.28389204e-01],
#        [ 2.85392016e-01],
#        [-5.36920607e-01],
#        [ 5.75238049e-01],
#        [-4.16683048e-01],
#        [ 1.77545294e-01],
#        [ 9.53460395e-01],
#        [ 4.46979791e-01],
#        [-1.97026893e-01],
#        [-1.34876654e-01],
#        [-4.41846639e-01],
#        [ 3.89010049e-02],
#        [ 4.93670732e-01],
#        [ 5.23490310e-01],
#        [-9.68048453e-01],
#        [-5.84128678e-01],
#        [ 3.01396728e-01],
#        [-8.12812820e-02],
#        [ 4.07197177e-01],
#        [-8.24322999e-01],
#        [ 2.18356982e-01],
#        [-9.33121383e-01],
#        [ 6.28415048e-01],
#        [-1.00633168e+00],
#        [-4.05587971e-01],
#        [-8.02110493e-01],
#        [-6.33431137e-01],
#        [ 7.74130702e-01],
#        [ 1.55382290e-01],
#        [-5.03123760e-01],
#        [-1.00606954e+00],
#        [-7.06413269e-01],
#        [-7.83452570e-01],
#        [-4.42328006e-01],
#        [-5.01168430e-01],
#        [ 5.50469577e-01],
#        [ 5.92698216e-01],
#        [ 1.12864133e-02],
#        [ 4.16832268e-02],
#        [-8.70319068e-01],
#        [ 2.09620908e-01],
#        [-1.00620234e+00],
#        [ 7.08721936e-01],
#        [-9.88959298e-02],
#        [-7.90793896e-02],
#        [ 6.44480586e-01],
#        [-6.82958543e-01],
#        [ 3.53058130e-01],
#        [ 9.13441554e-02],
#        [-9.83654186e-02],
#        [ 3.14589024e-01],
#        [ 3.77173781e-01],
#        [ 8.88425529e-01],
#        [ 1.03263251e-01],
#        [-9.12527263e-01],
#        [-2.31393296e-02],
#        [-7.99827054e-02],
#        [ 1.94655970e-01],
#        [-5.75130761e-01],
#        [-7.09810734e-01],
#        [ 1.21342674e-01],
#        [ 1.42978117e-01],
#        [-8.56597200e-02],
#        [-4.81935441e-01],
#        [-1.20049693e-01],
#        [ 5.57136118e-01],
#        [-3.10847491e-01],
#        [ 8.24100435e-01],
#        [-6.77742004e-01],
#        [-6.96836114e-01],
#        [ 6.44381225e-01],
#        [ 8.14314112e-02],
#        [ 5.89229539e-03],
#        [ 5.21605536e-02],
#        [ 9.20761883e-01],
#        [-1.55285403e-01],
#        [-2.64659405e-01],
#        [ 1.24479808e-01],
#        [ 7.95733392e-01],
#        [ 7.16900051e-01],
#        [-4.57435250e-01],
#        [-7.27524877e-01],
#        [ 4.66296971e-01],
#        [-4.90550518e-01],
#        [-9.22167599e-01],
#        [-7.81710207e-01],
#        [ 2.92292356e-01],
#        [ 6.56803191e-01],
#        [-4.82674003e-01],
#        [ 8.91443551e-01],
#        [ 7.87671506e-01],
#        [ 7.97034740e-01],
#        [ 6.18105054e-01],
#        [ 2.37926468e-02],
#        [ 3.35308671e-01],
#        [-1.00595915e+00],
#        [ 6.09294847e-02],
#        [-4.61733222e-01],
#        [-1.93109185e-01],
#        [ 4.75183040e-01],
#        [-7.15834439e-01],
#        [ 8.44754219e-01],
#        [ 4.12281990e-01],
#        [-4.74796891e-01],
#        [-6.06044352e-01],
#        [ 7.49212980e-01],
#        [-1.04024418e-01],
#        [-6.76340699e-01],
#        [-1.59915641e-01],
#        [-4.38188046e-01],
#        [-9.22015488e-01],
#        [ 5.86168289e-01],
#        [ 3.85544896e-01],
#        [ 2.90361553e-01],
#        [-3.57481360e-01],
#        [-1.58882543e-01],
#        [-1.35927826e-01],
#        [ 1.18497163e-01],
#        [-8.50377619e-01],
#        [ 8.19253147e-01],
#        [-5.92759073e-01],
#        [ 3.36990148e-01],
#        [ 1.44563928e-01],
#        [ 2.65413165e-01],
#        [ 7.11215079e-01],
#        [-5.21199346e-01],
#        [ 1.94401398e-01],
#        [-1.50919721e-01],
#        [ 6.64080024e-01],
#        [ 8.84065449e-01],
#        [ 4.36999410e-01],
#        [-6.98012531e-01],
#        [-3.06583252e-02],
#        [ 9.03596699e-01],
#        [-2.75136262e-01],
#        [-2.24955961e-01],
#        [ 9.52207386e-01],
#        [-6.91371024e-01],
#        [-2.37526760e-01],
#        [-5.51683605e-02],
#        [ 7.31741428e-01],
#        [-5.20833135e-01],
#        [ 2.21626475e-01],
#        [ 8.47524345e-01],
#        [ 9.33629632e-01],
#        [-3.51741880e-01],
#        [ 2.96665937e-01],
#        [ 3.72476876e-01],
#        [-2.78136075e-01],
#        [ 4.99603391e-01],
#        [ 1.16428331e-01],
#        [-1.49250463e-01],
#        [-6.37995064e-01],
#        [ 5.22713602e-01],
#        [ 5.41318774e-01],
#        [ 6.13605499e-01],
#        [ 5.01736224e-01],
#        [ 6.24010444e-01],
#        [-6.92198575e-01],
#        [ 8.14097077e-02],
#        [-3.25770974e-01],
#        [ 8.83120477e-01],
#        [ 1.72261242e-02],
#        [-7.70564735e-01],
#        [-7.47006655e-01],
#        [ 6.26687348e-01],
#        [-7.55423903e-02],
#        [ 8.54591094e-03],
#        [ 1.47851557e-01],
#        [ 1.57870814e-01],
#        [ 1.66712657e-01],
#        [-1.00580275e+00],
#        [-9.20519054e-01],
#        [-1.04910679e-01],
#        [-5.61966419e-01],
#        [ 4.42013368e-02],
#        [ 8.87550041e-02],
#        [ 3.09716403e-01],
#        [ 2.96425015e-01],
#        [ 8.78554165e-01],
#        [ 3.79261315e-01],
#        [ 2.58920461e-01],
#        [ 6.67534053e-01],
#        [ 6.63108110e-01],
#        [-3.54642332e-01],
#        [-1.77961484e-01],
#        [ 4.50290263e-01],
#        [-1.34493515e-01],
#        [-2.34624341e-01],
#        [ 2.58973569e-01],
#        [-5.05517721e-01],
#        [-1.32458791e-01],
#        [ 4.21096623e-01],
#        [ 6.62194431e-01],
#        [-6.39431715e-01],
#        [ 5.70219219e-01],
#        [-8.06878924e-01],
#        [-3.67697954e-01],
#        [ 1.02529310e-01],
#        [ 4.19660449e-01],
#        [-9.75969255e-01],
#        [-7.02580154e-01],
#        [ 9.21254337e-01],
#        [-2.82782853e-01],
#        [-5.84204972e-01],
#        [-2.87676930e-01],
#        [-1.03676893e-01],
#        [-4.50539410e-01],
#        [-1.88033506e-01],
#        [-1.32112458e-01],
#        [-9.67298523e-02],
#        [ 8.15027416e-01],
#        [ 2.43011311e-01],
#        [ 5.00460804e-01],
#        [ 4.74030465e-01],
#        [-8.03883851e-01],
#        [-9.13782269e-02],
#        [ 2.65978009e-01],
#        [-5.49972579e-02],
#        [-4.57424223e-01],
#        [-6.55927956e-01],
#        [-7.32589185e-01],
#        [ 6.48494244e-01],
#        [ 8.97348166e-01],
#        [-5.06776012e-03],
#        [-8.65677774e-01],
#        [ 4.44951579e-02],
#        [-5.72268367e-01],
#        [ 8.85250807e-01],
#        [-4.49837744e-02],
#        [-5.57155311e-01],
#        [ 7.74674535e-01],
#        [-8.16128552e-01],
#        [ 2.51827203e-02],
#        [ 1.52933955e-01],
#        [ 6.70868456e-01],
#        [ 7.91581035e-01],
#        [ 4.85146344e-01],
#        [-4.34322745e-01],
#        [-7.26532698e-01],
#        [-2.65478212e-02],
#        [-4.75664139e-01],
#        [-1.32628456e-01],
#        [ 1.88057318e-01],
#        [ 5.10833040e-02],
#        [-9.00037885e-01],
#        [-8.08968365e-01],
#        [-1.62839532e-01],
#        [ 6.98659495e-02],
#        [-2.97345340e-01],
#        [ 2.93791778e-02],
#        [ 1.89017758e-01],
#        [-6.25927389e-01],
#        [-1.81440368e-01],
#        [-9.08089995e-01],
#        [-4.14830685e-01],
#        [-4.26632464e-01],
#        [-9.44383919e-01],
#        [ 9.42509174e-01],
#        [ 6.68250382e-01],
#        [ 6.87933743e-01],
#        [-5.17909050e-01],
#        [-5.26967883e-01],
#        [-4.43955287e-02],
#        [ 9.23849344e-01],
#        [-2.03087881e-01],
#        [-9.02786016e-01],
#        [ 1.85725112e-02],
#        [ 9.32945192e-01],
#        [ 7.63930976e-01],
#        [ 2.59972692e-01],
#        [ 9.28928912e-01],
#        [-3.51735353e-02],
#        [ 9.00517881e-01],
#        [-6.34007633e-01],
#        [-6.46948874e-01],
#        [ 2.95447230e-01],
#        [ 6.91249490e-01],
#        [-1.51588231e-01],
#        [-6.90807402e-01],
#        [ 4.11576301e-01],
#        [-7.34382570e-01],
#        [-2.28551347e-02],
#        [-4.98415112e-01],
#        [ 2.71292955e-01],
#        [ 6.87083423e-01],
#        [-2.82847226e-01],
#        [-2.99191892e-01],
#        [-1.80523947e-01],
#        [-1.50849015e-01],
#        [-2.21926883e-01],
#        [ 4.71502542e-01],
#        [-6.40996769e-02],
#        [ 6.95705354e-01],
#        [ 1.67616785e-01],
#        [ 3.25456291e-01],
#        [ 1.78826392e-01],
#        [ 1.38568446e-01],
#        [-8.83215845e-01],
#        [-3.47607136e-02],
#        [-6.66462481e-01],
#        [-9.00188275e-03],
#        [ 6.90413117e-01],
#        [-4.15061176e-01],
#        [ 1.61284760e-01],
#        [-6.36724889e-01],
#        [ 8.22183967e-01],
#        [ 3.61676514e-01],
#        [ 3.09214473e-01],
#        [-1.24565177e-01],
#        [ 7.80828118e-01],
#        [ 1.33709788e-01],
#        [ 4.09259856e-01],
#        [-4.25213352e-02],
#        [ 7.21947849e-01],
#        [-3.05496395e-01],
#        [ 2.81807482e-01],
#        [ 6.19880259e-01],
#        [-3.28237295e-01],
#        [ 1.32954404e-01],
#        [-1.00600159e+00],
#        [-6.57340407e-01],
#        [ 3.08858585e-02],
#        [ 4.90873009e-01],
#        [-4.28580880e-01],
#        [-1.38432514e-02],
#        [-3.94895762e-01],
#        [-5.12644947e-01],
#        [ 5.37621975e-01],
#        [ 3.90964657e-01],
#        [-9.29391444e-01],
#        [ 1.41797245e-01],
#        [ 3.71119440e-01],
#        [ 4.08239424e-01],
#        [ 4.59842622e-01],
#        [-8.25009227e-01],
#        [-1.00594199e+00],
#        [ 1.69651464e-01],
#        [ 3.93172950e-01],
#        [ 1.84658974e-01],
#        [-7.35560298e-01],
#        [ 1.07586555e-01],
#        [ 9.12762165e-01],
#        [ 1.29399136e-01],
#        [-1.69586703e-01],
#        [ 1.73581108e-01],
#        [-3.66163671e-01],
#        [-2.62734771e-01],
#        [-2.72854924e-01],
#        [-8.06801915e-01],
#        [-1.92222103e-01],
#        [ 7.85654426e-01],
#        [-2.72109956e-01],
#        [-5.24517968e-02],
#        [-4.30369914e-01],
#        [-5.24388015e-01],
#        [ 6.34282351e-01],
#        [ 1.42258331e-01],
#        [ 5.93167901e-01],
#        [ 3.58910739e-01],
#        [ 9.10181344e-01],
#        [ 6.72655180e-02],
#        [-3.86065423e-01],
#        [-2.16594562e-01],
#        [ 6.04909539e-01],
#        [ 2.87846327e-01],
#        [-7.20631421e-01],
#        [-3.93667042e-01],
#        [ 7.39937648e-02],
#        [ 5.16132891e-01],
#        [-2.60703027e-01],
#        [ 4.72871885e-02],
#        [ 2.12946646e-02],
#        [-5.64989388e-01],
#        [ 8.15959394e-01],
#        [ 6.74133003e-01],
#        [ 3.23880650e-03],
#        [ 1.60660297e-02],
#        [-5.85474148e-02],
#        [-3.06746662e-01],
#        [-7.57690609e-01],
#        [-1.12990119e-01],
#        [-6.87531650e-01],
#        [-1.00638735e+00],
#        [ 7.36046582e-04],
#        [-7.44120598e-01],
#        [-7.62468100e-01],
#        [ 3.49305481e-01],
#        [-1.58854276e-01],
#        [-7.29617536e-01],
#        [-5.15575588e-01],
#        [ 8.56236890e-02],
#        [ 1.84349194e-01],
#        [ 2.97885180e-01],
#        [ 9.41900909e-01],
#        [-3.43953937e-01],
#        [ 5.94466627e-01],
#        [-2.58041233e-01],
#        [ 3.98738623e-01],
#        [ 2.90484838e-02],
#        [ 2.07706407e-01],
#        [ 7.35555470e-01],
#        [-6.92347705e-01],
#        [-1.17627345e-01],
#        [ 8.57501149e-01],
#        [ 9.22165155e-01],
#        [-2.20351174e-01],
#        [ 8.41819465e-01],
#        [ 7.04721868e-01],
#        [-1.49159715e-01],
#        [ 2.76288450e-01],
#        [ 8.86114180e-01],
#        [ 5.50978072e-03],
#        [-7.80258417e-01],
#        [ 6.01233020e-02],
#        [-3.50358397e-01],
#        [-7.10098147e-01],
#        [-7.66547583e-03],
#        [-8.79261553e-01],
#        [-3.76948714e-01],
#        [-2.67877966e-01],
#        [-2.52025515e-01],
#        [ 6.78053737e-01],
#        [ 3.83988678e-01],
#        [-2.13726059e-01],
#        [-3.64952445e-01],
#        [ 9.13473904e-01],
#        [ 7.27351248e-01],
#        [-4.75323379e-01],
#        [ 1.23756174e-02],
#        [ 2.18090236e-01],
#        [ 8.05226862e-01],
#        [-4.45220411e-01],
#        [ 9.54057932e-01],
#        [ 6.18571579e-01],
#        [-6.59104943e-01],
#        [ 5.97067177e-01],
#        [ 7.74054945e-01],
#        [ 8.35124314e-01],
#        [-2.20084414e-01],
#        [ 1.77953690e-02],
#        [ 8.92741501e-01],
#        [ 7.97686502e-02],
#        [ 2.55155951e-01],
#        [ 4.46523130e-01],
#        [ 1.35132587e-02],
#        [-6.80154026e-01],
#        [ 2.80329019e-01],
#        [ 7.93360233e-01],
#        [ 8.63687456e-01],
#        [ 6.10523283e-01],
#        [ 2.07814127e-02],
#        [-2.59640459e-02],
#        [ 9.24247384e-01],
#        [ 1.62706092e-01],
#        [-5.35571098e-01],
#        [-7.38205254e-01],
#        [-6.22890890e-02],
#        [ 1.49974152e-01],
#        [-7.35315323e-01],
#        [ 5.81017852e-01],
#        [ 9.26914692e-01],
#        [-3.13333124e-01],
#        [ 1.21608622e-01],
#        [-5.22304058e-01],
#        [ 9.16684330e-01],
#        [ 3.56857210e-01],
#        [-2.28716806e-01],
#        [ 8.25239360e-01],
#        [-1.16836898e-01],
#        [-2.89929807e-01],
#        [ 2.27400009e-02],
#        [-1.77120402e-01],
#        [-7.21035659e-01],
#        [-9.16441739e-01],
#        [-1.23355873e-01],
#        [-5.84802568e-01],
#        [-6.10243499e-01],
#        [ 4.56960440e-01],
#        [ 4.49618638e-01],
#        [-2.97832042e-01],
#        [ 8.89230549e-01],
#        [-5.54490924e-01],
#        [ 3.41932654e-01],
#        [ 9.44535375e-01],
#        [-2.34821752e-01],
#        [ 9.37209308e-01],
#        [-1.46141514e-01],
#        [-4.63506013e-01],
#        [ 8.99485499e-02],
#        [-1.96528301e-01],
#        [-2.33244136e-01],
#        [ 5.88494480e-01],
#        [ 7.19256341e-01],
#        [ 9.32984293e-01],
#        [-5.00545442e-01],
#        [ 7.21590757e-01],
#        [-1.55490920e-01],
#        [-3.05427253e-01],
#        [ 9.54977572e-01],
#        [-6.21744469e-02],
#        [ 5.25692642e-01],
#        [-9.61441994e-01],
#        [ 4.61530119e-01],
#        [-7.28133261e-01],
#        [-1.93733558e-01],
#        [ 7.09305465e-01],
#        [-5.28126776e-01],
#        [ 3.44349742e-01],
#        [-9.27114010e-01],
#        [ 3.02528262e-01],
#        [-6.24879658e-01],
#        [ 4.56558652e-02],
#        [-4.77039456e-01],
#        [ 7.69967318e-01],
#        [-8.15647423e-01],
#        [-5.02044618e-01],
#        [-5.87101758e-01],
#        [-3.97206068e-01],
#        [-2.98490584e-01],
#        [ 2.48560339e-01],
#        [ 2.14802966e-01],
#        [-9.05582249e-01],
#        [ 1.82636827e-01],
#        [ 4.07111168e-01],
#        [-2.37204090e-01],
#        [ 9.85921100e-02],
#        [-7.89731383e-01],
#        [-4.43193495e-01],
#        [ 3.37611258e-01],
#        [ 8.83808434e-01],
#        [ 7.24826694e-01],
#        [ 4.42866415e-01],
#        [ 2.80619830e-01],
#        [-3.16951513e-01],
#        [-4.77006793e-01],
#        [ 6.21881783e-01],
#        [ 3.62274140e-01],
#        [-6.51547074e-01],
#        [ 9.27922606e-01],
#        [-3.12652677e-01],
#        [-9.23228443e-01],
#        [ 1.13007016e-01],
#        [ 1.10587314e-01],
#        [-5.70772767e-01],
#        [-2.18853459e-01],
#        [-1.42952085e-01],
#        [ 9.50739980e-01],
#        [-1.79193214e-01],
#        [-8.09697866e-01],
#        [-5.86657822e-01],
#        [ 1.78113371e-01],
#        [-1.64590821e-01],
#        [-3.20389748e-01],
#        [ 1.26892373e-01],
#        [-4.88327622e-01],
#        [ 5.23024976e-01],
#        [-3.91794920e-01],
#        [-2.16284826e-01],
#        [-6.95446968e-01],
#        [ 2.09573030e-01],
#        [-9.18576658e-01],
#        [-1.85095653e-01],
#        [ 6.75689042e-01],
#        [ 7.60889590e-01],
#        [-1.00586390e+00],
#        [ 1.63892195e-01],
#        [-4.00892645e-02],
#        [ 2.62692064e-01],
#        [ 5.60766101e-01],
#        [ 9.08949316e-01],
#        [-2.15695977e-01],
#        [-4.19576436e-01],
#        [-2.12424219e-01],
#        [-7.16853082e-01],
#        [-1.00625932e+00],
#        [-9.16656613e-01],
#        [ 9.31595266e-01],
#        [ 4.80300307e-01],
#        [ 9.12446797e-01]], dtype=float32)

# %%
X_test[0]
# Out:
# array([[-0.54182783, -0.54172822,  0.33261505]])

# %%
arr = X_test
X_test0 = arr[:1]
X_test0
# Out:
# array([[[-0.54182783, -0.54172822,  0.33261505]]])

# %%
valid_predictions_df=pd.DataFrame(valid_predictions)
valid_predictions_df.columns = ["Tension"]
valid_predictions_df
# Out:
#       Tension
# 0   -0.086205
# 1    0.835223
# 2    0.198912
# 3    0.939132
# 4   -0.173498
# ..        ...
# 764 -1.006259
# 765 -0.916657
# 766  0.931595
# 767  0.480300
# 768  0.912447
#
# [769 rows x 1 columns]

# %%
k= y_valid.to_numpy()
k_df = pd.DataFrame(k)
k_df.columns  = ["Valid_Tension"]
k_df
# Out:
#      Valid_Tension
# 0        -0.084579
# 1         0.844640
# 2         0.191283
# 3         0.913606
# 4        -0.189842
# ..             ...
# 764      -0.970242
# 765      -0.879498
# 766       0.931755
# 767       0.478034
# 768       0.939014
#
# [769 rows x 1 columns]

# %%
k_df.describe()
# Out:
#        Valid_Tension
# count     769.000000
# mean       -0.021179
# std         0.539739
# min        -1.006539
# 25%        -0.458445
# 50%        -0.048282
# 75%         0.409069
# max         0.978942

# %%
ValidPre = pd.concat( [k_df,valid_predictions_df],axis=1)
ValidPre.head(5)
corr = ValidPre.corr()
print("corr")
for i in range(0,1):    
    print(format(corr[valid_predictions_df.columns[i]][k_df.columns[i]]*100,'.2f')+'%',k_df.columns[i])
corr
# Out:
# corr
# 99.90% Valid_Tension
#                Valid_Tension  Tension
# Valid_Tension        1.00000  0.99903
# Tension              0.99903  1.00000

# %%
alpa=0.1

ValidPre.plot(kind="scatter", x= "Valid_Tension",y= "Tension",alpha = alpa)
plt.savefig('H:/Jupyter_project/wearableActuator/savefig/'+dataname+'.png')

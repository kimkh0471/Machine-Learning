# %%
import os, sklearn, math
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from joblib import dump, load

tf.random.set_seed(42)

data = '230630_data'
dataname = data+'_1'
filename = 'myLearningData/'+data+'.csv'
SD = pd.read_csv(filename)
SD=SD.iloc[:,:5]
SensorData = SD

# %%
SD

# %%
SD.describe()

# %%
SDz=(SD.loc[:,'Distance'])
SDz.plot()

# %%
SDy = SD.iloc[:,1]
SDy
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.01
# 4       0.03
#         ...
# 3878    0.00
# 3879    0.00
# 3880    0.00
# 3881    0.00
# 3882    0.00
# Name: Distance, Length: 3883, dtype: float64

# %%
X = SD.iloc[:,[3]]
y = SD.iloc[:,[1]]

# %%
X
# Out:
#       Resistance
# 0           8.46
# 1           8.46
# 2           8.46
# 3           8.39
# 4           8.39
# ...          ...
# 3878        8.71
# 3879        8.71
# 3880        8.65
# 3881        8.71
# 3882        8.71
#
# [3883 rows x 1 columns]

# %%
y.sample(5)
# Out:
#       Distance
# 1620      3.66
# 3056     10.19
# 2041      1.25
# 2856     11.74
# 1664      3.09

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size = 0.01, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.20, random_state=42)

# %%
X_sum = len(X_train)+len(X_valid)+len(X_test)
X_train_per = int(len(X_train)/X_sum*100)
X_valid_per = int(len(X_valid)/X_sum*100)
X_test_per = int(len(X_test)/X_sum*100)

print('X_train: ',len(X_train),'ea',X_train_per,'%   ', 
      'X_valid: ',len(X_valid),'ea',X_valid_per,'%   ',
      'X_test: ',len(X_test),'ea',X_test_per,'%',)
# Out:
# X_train:  3075 ea 79 %    X_valid:  769 ea 19 %    X_test:  39 ea 1 %

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
import pickle
from joblib import dump, load

file_name = 'myScaler/'+dataname+'_LSTM'+'_SS.pkl'
dump(scaler, file_name)
# Out:
# ['myScaler/230630_data_1_SS.pkl']

# %%
from tensorflow import keras
model = keras.models.Sequential([    
    keras.layers.Dense(16, activation="relu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),   
    keras.layers.Dense(16, activation="relu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),        
    keras.layers.Dense(16, activation="relu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),        
    keras.layers.Dense(1)
    
])

#model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3, momentum = 0.9,nesterov = True))
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.RMSprop(learning_rate=1e-3, rho = 0.9))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 16)                32
#
#  dense_17 (Dense)            (None, 16)                272
#
#  dense_18 (Dense)            (None, 16)                272
#
#  dense_19 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 593
# Trainable params: 593
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Callback (best, early stopping, tensorboard)

# %%
import os 
#root_logdir = os.path.join(os.curdir, 'mylog/'+data)
root_logdir = os.path.join(os.curdir, 'mylog/'+'230630')

def get_run_logdir():
    import time
    run_id= time.strftime("%m%d_%Hh%Mm%Ss"+dataname)
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()

# %%
K = keras.backend
class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, rate)

# %%
dataname
# Out:
# '230630_data_1'

# %%
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 10, restore_best_weights = True)
n_epochs = 300
batch_size = 1
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs, max_rate=0.05)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle,early_stopping_cb,tensorboard_cb])
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:5]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/300
#  1/97 [..............................] - ETA: 2:00 - loss: 45.6481WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0016s vs `on_train_batch_end` time: 0.0125s). Check your callbacks.
# 97/97 [==============================] - 2s 8ms/step - loss: 4.5268 - val_loss: 1.2032
# Epoch 2/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2506 - val_loss: 1.1094
# Epoch 3/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2340 - val_loss: 0.3264
# Epoch 4/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2170 - val_loss: 0.1554
# Epoch 5/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1897 - val_loss: 0.1360
# Epoch 6/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1809 - val_loss: 0.1889
# Epoch 7/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1807 - val_loss: 0.3683
# Epoch 8/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1609 - val_loss: 0.3086
# Epoch 9/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1648 - val_loss: 0.2893
# Epoch 10/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1596 - val_loss: 0.1369
# Epoch 11/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1575 - val_loss: 0.1185
# Epoch 12/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1457 - val_loss: 0.1258
# Epoch 13/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1530 - val_loss: 0.1714
# Epoch 14/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1474 - val_loss: 0.1393
# Epoch 15/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1422 - val_loss: 0.1342
# Epoch 16/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1406 - val_loss: 0.1495
# Epoch 17/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1404 - val_loss: 0.3216
# Epoch 18/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1411 - val_loss: 0.5663
# Epoch 19/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1335 - val_loss: 0.4421
# Epoch 20/300
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1373 - val_loss: 0.1575
# Epoch 21/300
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1380 - val_loss: 0.2841
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1179
# 1/1 [==============================] - 0s 88ms/step

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./mylog/230630 --port=1630
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 1630 (pid 22236), started 0:07:21 ago. (Use '!kill 22236' to kill it.)
#       <iframe id="tensorboard-frame-a840aab4304f6b21" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a840aab4304f6b21");
#           const url = new URL("/", window.location);
#           const port = 1630;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.save('H:/Jupyter_project/wearableActuator/myModel/'+dataname'_LSTM'+'.h5')

# %%
model = tf.keras.models.load_model('myModel/'+dataname+'.h5')
scaler = load(file_name)
valid_predictions = model.predict(X_valid)
# Out:
# 25/25 [==============================] - 0s 1ms/step

# %%
X_valid
# Out:
# array([[ 0.42769626],
#        [ 1.25884785],
#        [ 0.93542405],
#        [ 1.48833605],
#        [-0.83746152],
#        [-1.37134859],
#        [-0.12164857],
#        [-0.09905646],
#        [-1.11926828],
#        [ 0.70236867],
#        [-1.67693652],
#        [-0.53306266],
#        [ 1.50498287],
#        [-0.68882926],
#        [-0.61748578],
#        [ 1.13280769],
#        [ 1.18037001],
#        [ 1.22674328],
#        [ 1.48833605],
#        [ 1.08643443],
#        [ 0.09357094],
#        [-1.25125373],
#        [ 0.19345182],
#        [-1.68407087],
#        [ 1.07097667],
#        [ 0.9056976 ],
#        [-0.72925724],
#        [-1.51165745],
#        [ 0.78798085],
#        [ 0.61794555],
#        [-0.53306266],
#        [-1.45458266],
#        [-1.59845868],
#        [-0.81843659],
#        [ 0.63221425],
#        [-0.0158224 ],
#        [-0.43674895],
#        [-1.01819835],
#        [-1.07289502],
#        [ 0.30879045],
#        [-0.76849615],
#        [-0.19180299],
#        [ 1.05551892],
#        [ 0.8605134 ],
#        [-1.59132434],
#        [-1.08240748],
#        [-1.42961244],
#        [-1.30357228],
#        [ 0.9651505 ],
#        [-1.65315536],
#        [-0.28336046],
#        [ 0.87597115],
#        [ 0.89023985],
#        [-1.24293032],
#        [-0.8862129 ],
#        [-1.42961244],
#        [-1.38799541],
#        [-0.22628568],
#        [-0.82794906],
#        [-1.06457161],
#        [-0.51165961],
#        [ 1.08643443],
#        [-1.27741301],
#        [ 0.99487696],
#        [-0.62699825],
#        [ 1.14826545],
#        [-0.71855572],
#        [-1.66147876],
#        [ 1.43839562],
#        [-1.33805497],
#        [ 1.02579247],
#        [ 0.64529389],
#        [-1.379672  ],
#        [ 0.29571081],
#        [-0.80773507],
#        [ 1.50498287],
#        [-0.83746152],
#        [-0.12164857],
#        [ 0.54898018],
#        [ 0.67383128],
#        [ 0.30879045],
#        [-1.40464222],
#        [-1.12759169],
#        [ 1.05551892],
#        [-1.51879179],
#        [ 0.34802937],
#        [-0.40464439],
#        [ 0.29571081],
#        [-0.33805714],
#        [-1.70666297],
#        [ 0.1316208 ],
#        [-1.3202191 ],
#        [-1.29524888],
#        [ 0.36110901],
#        [-1.65315536],
#        [ 0.59059721],
#        [ 0.70236867],
#        [ 1.37299742],
#        [-1.50333404],
#        [-0.54376418],
#        [ 0.19345182],
#        [ 1.30759923],
#        [ 0.57632852],
#        [ 1.02579247],
#        [-0.74828217],
#        [-1.63056325],
#        [-1.34637837],
#        [-1.48668723],
#        [-1.01819835],
#        [-1.66147876],
#        [ 0.60367685],
#        [-0.38324134],
#        [-0.71855572],
#        [-0.11094704],
#        [ 0.77371216],
#        [-0.31665409],
#        [ 0.60367685],
#        [-1.68407087],
#        [ 1.08643443],
#        [-1.48668723],
#        [ 1.02579247],
#        [-1.67693652],
#        [ 0.53471149],
#        [-0.84697399],
#        [-1.45458266],
#        [ 0.03292898],
#        [ 0.70236867],
#        [-1.35470178],
#        [-0.41534591],
#        [-0.32735561],
#        [-1.22509445],
#        [-0.28336046],
#        [-1.51165745],
#        [-1.68407087],
#        [ 0.93542405],
#        [-1.42128903],
#        [-0.0752753 ],
#        [ 1.45504243],
#        [-0.58538121],
#        [ 1.3397038 ],
#        [ 0.9651505 ],
#        [-0.36064924],
#        [-0.57586875],
#        [ 0.9794192 ],
#        [-1.54376201],
#        [-0.61748578],
#        [-1.64602101],
#        [-0.50214715],
#        [-1.49501063],
#        [ 0.93542405],
#        [ 0.32187009],
#        [-1.5271152 ],
#        [-1.09191995],
#        [-0.86718797],
#        [ 0.05671014],
#        [ 1.24339009],
#        [ 1.37299742],
#        [ 0.60367685],
#        [-1.68407087],
#        [-0.05149414],
#        [-0.99085001],
#        [ 1.40510199],
#        [ 0.67383128],
#        [ 1.10189218],
#        [ 0.48120387],
#        [ 0.54898018],
#        [-1.1810993 ],
#        [-0.74828217],
#        [ 0.36110901],
#        [ 0.4407759 ],
#        [-0.84697399],
#        [-1.24293032],
#        [ 1.45504243],
#        [ 0.99487696],
#        [ 0.65956258],
#        [ 0.87597115],
#        [ 0.37418865],
#        [-1.53543861],
#        [ 1.3397038 ],
#        [-1.57467752],
#        [ 0.37418865],
#        [ 0.77371216],
#        [ 0.94969275],
#        [-1.33805497],
#        [-0.76849615],
#        [ 0.93542405],
#        [-0.38324134],
#        [-1.55089636],
#        [-0.99917342],
#        [ 1.08643443],
#        [ 0.24458132],
#        [-0.7387697 ],
#        [ 0.81651825],
#        [-1.27741301],
#        [ 0.831976  ],
#        [ 1.48833605],
#        [ 0.61794555],
#        [ 0.15659102],
#        [ 0.25766096],
#        [-1.30357228],
#        [ 0.61794555],
#        [ 0.63221425],
#        [ 1.18037001],
#        [-1.59132434],
#        [-0.83746152],
#        [ 0.30879045],
#        [ 0.45385554],
#        [ 0.52163185],
#        [-1.3202191 ],
#        [ 0.87597115],
#        [-1.51165745],
#        [ 0.93542405],
#        [-1.68407087],
#        [-0.52236114],
#        [-1.35470178],
#        [-1.56754318],
#        [ 1.18037001],
#        [-0.08716588],
#        [-1.40464222],
#        [-1.66861311],
#        [-1.55089636],
#        [-1.69239427],
#        [-0.59608274],
#        [-1.40464222],
#        [ 1.19582777],
#        [ 0.9199663 ],
#        [-0.41534591],
#        [ 0.61794555],
#        [-1.67693652],
#        [ 0.06978978],
#        [-1.67693652],
#        [ 0.99487696],
#        [-0.64721223],
#        [ 0.36110901],
#        [ 0.9056976 ],
#        [-1.03722328],
#        [ 0.42769626],
#        [ 0.70236867],
#        [-0.65791375],
#        [ 0.29571081],
#        [ 1.05551892],
#        [ 1.43839562],
#        [ 0.73090607],
#        [-1.47836382],
#        [ 0.54898018],
#        [-0.62699825],
#        [ 0.0210384 ],
#        [-1.39631881],
#        [-1.15494003],
#        [ 0.74517476],
#        [-0.12164857],
#        [-0.61748578],
#        [-0.59608274],
#        [-0.70904325],
#        [ 1.19582777],
#        [-0.24887778],
#        [ 1.24339009],
#        [-1.09191995],
#        [-1.12759169],
#        [ 1.27549466],
#        [-0.27146988],
#        [-0.43674895],
#        [-0.31665409],
#        [ 1.43839562],
#        [ 0.27074059],
#        [-1.00868588],
#        [ 0.74517476],
#        [ 1.21128552],
#        [ 1.3397038 ],
#        [-0.62699825],
#        [-1.65315536],
#        [ 0.64529389],
#        [-0.62699825],
#        [-1.48668723],
#        [-1.62223985],
#        [ 0.9794192 ],
#        [ 0.9794192 ],
#        [-0.68882926],
#        [ 1.37299742],
#        [ 1.19582777],
#        [ 1.22674328],
#        [ 1.22674328],
#        [ 0.59059721],
#        [ 1.02579247],
#        [-1.67693652],
#        [-0.28336046],
#        [-0.63769977],
#        [ 0.08168036],
#        [ 1.1637232 ],
#        [-1.56754318],
#        [ 1.29095241],
#        [ 0.52163185],
#        [-0.59608274],
#        [-1.44625925],
#        [ 1.32305698],
#        [-0.68882926],
#        [-1.10024336],
#        [-0.81843659],
#        [-0.57586875],
#        [-1.67693652],
#        [ 1.21128552],
#        [ 1.05551892],
#        [ 0.9794192 ],
#        [-1.16326343],
#        [ 0.18156124],
#        [ 0.32187009],
#        [ 0.74517476],
#        [-1.35470178],
#        [ 1.24339009],
#        [-0.9147503 ],
#        [ 0.37418865],
#        [-0.08716588],
#        [ 0.99487696],
#        [ 1.02579247],
#        [-0.77919768],
#        [ 0.87597115],
#        [ 0.2196111 ],
#        [ 0.9794192 ],
#        [ 1.48833605],
#        [ 1.11734994],
#        [-1.06457161],
#        [ 0.53471149],
#        [ 1.45504243],
#        [-0.98133755],
#        [ 0.10665058],
#        [ 1.48833605],
#        [-1.63056325],
#        [-0.92426276],
#        [-0.5544657 ],
#        [ 1.3397038 ],
#        [-0.68882926],
#        [ 0.9651505 ],
#        [ 1.40510199],
#        [ 1.43839562],
#        [-1.16326343],
#        [ 0.25766096],
#        [ 0.42769626],
#        [-1.03722328],
#        [ 1.1637232 ],
#        [ 0.78798085],
#        [ 0.28263118],
#        [-1.55921977],
#        [ 0.78798085],
#        [ 1.19582777],
#        [ 0.93542405],
#        [ 0.73090607],
#        [ 0.9199663 ],
#        [-1.12759169],
#        [ 0.73090607],
#        [-0.2143951 ],
#        [ 1.37299742],
#        [ 0.59059721],
#        [-1.28573641],
#        [-1.67693652],
#        [ 0.87597115],
#        [-0.62699825],
#        [ 0.63221425],
#        [-0.12164857],
#        [-0.08716588],
#        [-0.05149414],
#        [-1.66861311],
#        [-1.68407087],
#        [ 0.34802937],
#        [-1.47836382],
#        [ 0.65956258],
#        [-0.24887778],
#        [ 1.04006116],
#        [ 0.9651505 ],
#        [ 1.35635061],
#        [ 1.05551892],
#        [ 0.2196111 ],
#        [ 0.9651505 ],
#        [ 0.94969275],
#        [-0.39394286],
#        [ 0.23150168],
#        [ 1.13280769],
#        [-0.7387697 ],
#        [ 0.08168036],
#        [ 0.93542405],
#        [-0.75898369],
#        [ 0.33494973],
#        [ 0.50736315],
#        [ 0.94969275],
#        [-0.96231262],
#        [ 1.24339009],
#        [-1.70666297],
#        [-0.33805714],
#        [ 0.77371216],
#        [ 0.56205982],
#        [-1.59845868],
#        [-1.07289502],
#        [ 1.45504243],
#        [-0.06338472],
#        [-1.41296563],
#        [-0.16921089],
#        [ 0.34802937],
#        [-0.59608274],
#        [-0.80773507],
#        [-0.70904325],
#        [ 0.34802937],
#        [ 1.22674328],
#        [ 0.15659102],
#        [ 0.70236867],
#        [ 0.65956258],
#        [-1.2690896 ],
#        [-0.65791375],
#        [ 0.23150168],
#        [ 0.41342756],
#        [-1.34637837],
#        [-1.04554668],
#        [-1.12759169],
#        [ 1.22674328],
#        [ 1.45504243],
#        [ 0.53471149],
#        [-1.49501063],
#        [-0.33805714],
#        [-0.80773507],
#        [ 1.37299742],
#        [ 0.48120387],
#        [-1.379672  ],
#        [ 1.3397038 ],
#        [-1.64602101],
#        [-0.38324134],
#        [ 0.80224955],
#        [ 0.99487696],
#        [ 1.19582777],
#        [ 0.61794555],
#        [-1.30357228],
#        [-1.11926828],
#        [-0.4807441 ],
#        [-0.66861528],
#        [ 0.25766096],
#        [ 0.04481956],
#        [-0.33805714],
#        [-1.55089636],
#        [-1.70666297],
#        [-0.83746152],
#        [ 0.71663737],
#        [-0.2143951 ],
#        [ 0.60367685],
#        [ 0.81651825],
#        [-0.93377523],
#        [ 0.23150168],
#        [-1.59132434],
#        [-1.27741301],
#        [-1.29524888],
#        [-1.66861311],
#        [ 1.50498287],
#        [ 1.29095241],
#        [ 1.30759923],
#        [-1.33805497],
#        [-0.79822261],
#        [-0.54376418],
#        [ 1.45504243],
#        [-0.84697399],
#        [-1.45458266],
#        [ 0.59059721],
#        [ 1.50498287],
#        [ 1.11734994],
#        [ 0.2196111 ],
#        [ 1.4217488 ],
#        [-0.52236114],
#        [ 1.48833605],
#        [-0.99085001],
#        [-0.96231262],
#        [ 0.25766096],
#        [ 1.04006116],
#        [ 0.29571081],
#        [-1.11926828],
#        [ 1.11734994],
#        [-1.19893517],
#        [ 0.49428351],
#        [-0.72925724],
#        [ 0.19345182],
#        [ 1.01033471],
#        [-0.16921089],
#        [-1.01819835],
#        [ 0.14351138],
#        [-0.74828217],
#        [-0.89572537],
#        [ 0.65956258],
#        [-0.58538121],
#        [ 1.07097667],
#        [-0.05149414],
#        [ 0.99487696],
#        [-0.0158224 ],
#        [ 0.78798085],
#        [-1.51879179],
#        [-0.52236114],
#        [-0.99085001],
#        [-0.44745048],
#        [ 0.9794192 ],
#        [-0.52236114],
#        [ 0.8605134 ],
#        [-1.47122947],
#        [ 1.24339009],
#        [ 0.4407759 ],
#        [ 0.29571081],
#        [ 0.29571081],
#        [ 1.1637232 ],
#        [-0.13353915],
#        [ 0.48120387],
#        [ 0.49428351],
#        [ 1.3397038 ],
#        [-0.16921089],
#        [ 0.25766096],
#        [ 0.9199663 ],
#        [-0.32735561],
#        [-0.14542973],
#        [-1.67693652],
#        [-1.05505915],
#        [ 0.60367685],
#        [ 0.63221425],
#        [-0.4807441 ],
#        [-0.47004258],
#        [-0.49144563],
#        [-0.74828217],
#        [ 0.78798085],
#        [ 0.45385554],
#        [-1.68407087],
#        [-0.13353915],
#        [ 1.05551892],
#        [ 0.52163185],
#        [ 0.63221425],
#        [-1.38799541],
#        [-1.66147876],
#        [ 0.8605134 ],
#        [ 0.46693518],
#        [ 0.9056976 ],
#        [-1.13710416],
#        [ 0.73090607],
#        [ 1.45504243],
#        [ 0.77371216],
#        [ 0.25766096],
#        [-0.00393182],
#        [-0.40464439],
#        [-0.00393182],
#        [-0.03960356],
#        [-1.27741301],
#        [-0.8862129 ],
#        [ 1.14826545],
#        [-0.13353915],
#        [ 0.42769626],
#        [-1.29524888],
#        [-1.35470178],
#        [ 1.22674328],
#        [-0.09905646],
#        [ 0.8462447 ],
#        [ 1.04006116],
#        [ 1.45504243],
#        [-0.28336046],
#        [-1.14542756],
#        [-0.87670044],
#        [ 1.22674328],
#        [ 0.28263118],
#        [-1.11926828],
#        [-0.50214715],
#        [ 0.67383128],
#        [ 0.74517476],
#        [-0.96231262],
#        [-0.33805714],
#        [-0.38324134],
#        [-0.85648645],
#        [ 1.27549466],
#        [ 0.9651505 ],
#        [-0.44745048],
#        [-0.38324134],
#        [ 0.38726828],
#        [-1.02771081],
#        [-1.69239427],
#        [ 0.30879045],
#        [-1.03722328],
#        [-1.67693652],
#        [-0.45934106],
#        [-1.22509445],
#        [-1.61391644],
#        [ 0.42769626],
#        [ 0.24458132],
#        [-1.66147876],
#        [-1.3285425 ],
#        [ 0.70236867],
#        [ 0.0210384 ],
#        [ 0.27074059],
#        [ 1.50498287],
#        [-1.08240748],
#        [ 0.831976  ],
#        [-0.00393182],
#        [ 0.46693518],
#        [-0.40464439],
#        [ 0.93542405],
#        [ 1.32305698],
#        [-1.54376201],
#        [ 0.30879045],
#        [ 1.30759923],
#        [ 1.48833605],
#        [-0.93377523],
#        [ 1.27549466],
#        [ 0.99487696],
#        [-0.78871014],
#        [ 0.20653146],
#        [ 1.3397038 ],
#        [ 0.56205982],
#        [-1.21677105],
#        [-0.31665409],
#        [-0.28336046],
#        [-1.09191995],
#        [-0.44745048],
#        [-1.67693652],
#        [-0.34994772],
#        [-0.02771298],
#        [-0.0752753 ],
#        [ 1.27549466],
#        [ 1.10189218],
#        [ 0.04481956],
#        [-0.40464439],
#        [ 1.40510199],
#        [ 1.3397038 ],
#        [-1.28573641],
#        [ 0.63221425],
#        [ 0.09357094],
#        [ 1.19582777],
#        [-0.51165961],
#        [ 1.48833605],
#        [ 0.9199663 ],
#        [-1.59132434],
#        [ 0.9199663 ],
#        [ 1.11734994],
#        [ 1.27549466],
#        [-0.8862129 ],
#        [ 0.64529389],
#        [ 1.48833605],
#        [-0.2369872 ],
#        [ 0.2196111 ],
#        [ 0.54898018],
#        [-0.41534591],
#        [-1.51879179],
#        [ 0.99487696],
#        [ 1.37299742],
#        [ 1.29095241],
#        [ 0.9056976 ],
#        [ 0.64529389],
#        [ 0.54898018],
#        [ 1.4217488 ],
#        [-0.06338472],
#        [-0.80773507],
#        [-1.20844764],
#        [ 0.38726828],
#        [ 0.80224955],
#        [-1.59132434],
#        [ 0.831976  ],
#        [ 1.4217488 ],
#        [-0.24887778],
#        [-0.13353915],
#        [-0.69834173],
#        [ 1.45504243],
#        [ 1.02579247],
#        [-0.00393182],
#        [ 1.24339009],
#        [-0.68882926],
#        [-1.05505915],
#        [-0.40464439],
#        [ 0.1316208 ],
#        [-1.64602101],
#        [-1.59845868],
#        [ 0.29571081],
#        [-1.42128903],
#        [-0.95280016],
#        [ 0.63221425],
#        [ 0.53471149],
#        [-0.13353915],
#        [ 1.37299742],
#        [-0.78871014],
#        [ 0.38726828],
#        [ 1.47168924],
#        [-0.96231262],
#        [ 1.43839562],
#        [-0.72925724],
#        [-0.59608274],
#        [-0.26076836],
#        [ 0.09357094],
#        [-0.97182508],
#        [ 1.21128552],
#        [ 1.07097667],
#        [ 1.43839562],
#        [-0.64721223],
#        [ 1.08643443],
#        [ 0.20653146],
#        [-1.08240748],
#        [ 1.50498287],
#        [ 0.40034792],
#        [ 0.77371216],
#        [-1.59132434],
#        [ 1.1637232 ],
#        [-1.12759169],
#        [-0.87670044],
#        [ 1.05551892],
#        [-0.71855572],
#        [ 0.40034792],
#        [-1.63056325],
#        [ 0.9794192 ],
#        [-0.99085001],
#        [ 0.67383128],
#        [-0.67812774],
#        [ 1.18037001],
#        [-1.70666297],
#        [-0.65791375],
#        [-1.51165745],
#        [-0.39394286],
#        [-1.06457161],
#        [ 0.9794192 ],
#        [ 0.87597115],
#        [-1.46290607],
#        [ 0.831976  ],
#        [ 1.11734994],
#        [ 0.06978978],
#        [-0.2143951 ],
#        [-1.69952862],
#        [-1.25125373],
#        [ 1.05551892],
#        [ 1.43839562],
#        [ 1.3397038 ],
#        [ 0.59059721],
#        [ 0.25766096],
#        [-0.28336046],
#        [-1.379672  ],
#        [ 0.8605134 ],
#        [ 1.07097667],
#        [-1.48668723],
#        [ 1.4217488 ],
#        [-1.09191995],
#        [-1.62223985],
#        [-0.15732031],
#        [-0.16921089],
#        [-0.79822261],
#        [ 0.1316208 ],
#        [ 0.24458132],
#        [ 1.50498287],
#        [ 0.2196111 ],
#        [-1.28573641],
#        [-1.51879179],
#        [ 0.89023985],
#        [ 0.1684816 ],
#        [-1.05505915],
#        [-0.15732031],
#        [-0.69834173],
#        [ 1.21128552],
#        [-0.38324134],
#        [ 0.14351138],
#        [-1.11926828],
#        [ 0.09357094],
#        [-1.61391644],
#        [ 0.1316208 ],
#        [ 1.27549466],
#        [ 1.11734994],
#        [-1.66861311],
#        [-0.06338472],
#        [-0.53306266],
#        [ 0.18156124],
#        [ 1.22674328],
#        [ 1.4217488 ],
#        [-0.94328769],
#        [-1.19893517],
#        [-0.92426276],
#        [-1.64602101],
#        [-1.68407087],
#        [-1.48668723],
#        [ 1.45504243],
#        [ 0.59059721],
#        [ 1.40510199]])

# %%
valid_predictions
# Out:
# array([[ 7.095885  ],
#        [10.606788  ],
#        [ 9.01933   ],
#        [11.799185  ],
#        [ 3.2022488 ],
#        [ 1.3865738 ],
#        [ 5.2923756 ],
#        [ 5.361849  ],
#        [ 2.3436534 ],
#        [ 8.057832  ],
#        [ 0.35007194],
#        [ 4.228915  ],
#        [11.885681  ],
#        [ 3.770692  ],
#        [ 4.024582  ],
#        [ 9.951894  ],
#        [10.199023  ],
#        [10.439974  ],
#        [11.799185  ],
#        [ 9.710944  ],
#        [ 5.924995  ],
#        [ 1.8270792 ],
#        [ 6.275521  ],
#        [ 0.33702514],
#        [ 9.630626  ],
#        [ 8.885758  ],
#        [ 3.6102593 ],
#        [ 0.8948339 ],
#        [ 8.376845  ],
#        [ 7.762169  ],
#        [ 4.228915  ],
#        [ 1.094864  ],
#        [ 0.5906225 ],
#        [ 3.273987  ],
#        [ 7.8121405 ],
#        [ 5.6192684 ],
#        [ 4.5107117 ],
#        [ 2.6570609 ],
#        [ 2.5263698 ],
#        [ 6.679456  ],
#        [ 3.4622998 ],
#        [ 5.2086096 ],
#        [ 9.558962  ],
#        [ 8.681884  ],
#        [ 0.61562675],
#        [ 2.4888892 ],
#        [ 1.1823769 ],
#        [ 1.6266396 ],
#        [ 9.152903  ],
#        [ 0.40769747],
#        [ 5.059063  ],
#        [ 8.752185  ],
#        [ 8.8163    ],
#        [ 1.8589675 ],
#        [ 3.0273187 ],
#        [ 1.1823769 ],
#        [ 1.3282318 ],
#        [ 5.1457767 ],
#        [ 3.238118  ],
#        [ 2.5444164 ],
#        [ 4.280718  ],
#        [ 9.710944  ],
#        [ 1.7268591 ],
#        [ 9.286475  ],
#        [ 4.001559  ],
#        [10.032211  ],
#        [ 3.6520307 ],
#        [ 0.38309804],
#        [11.539699  ],
#        [ 1.5032574 ],
#        [ 9.425389  ],
#        [ 7.8579473 ],
#        [ 1.3574029 ],
#        [ 6.633649  ],
#        [ 3.3143394 ],
#        [11.885681  ],
#        [ 3.2022488 ],
#        [ 5.2923756 ],
#        [ 7.5206413 ],
#        [ 7.9578905 ],
#        [ 6.679456  ],
#        [ 1.2698901 ],
#        [ 2.310858  ],
#        [ 9.558962  ],
#        [ 0.86983085],
#        [ 6.8168774 ],
#        [ 4.6241193 ],
#        [ 6.633649  ],
#        [ 4.8612967 ],
#        [ 0.301136  ],
#        [ 6.0519257 ],
#        [ 1.5657673 ],
#        [ 1.6585279 ],
#        [ 6.8626842 ],
#        [ 0.40769744],
#        [ 7.6663904 ],
#        [ 8.057832  ],
#        [11.199897  ],
#        [ 0.9240049 ],
#        [ 4.2030134 ],
#        [ 6.275521  ],
#        [10.860093  ],
#        [ 7.61642   ],
#        [ 9.425389  ],
#        [ 3.5385213 ],
#        [ 0.47810602],
#        [ 1.4740872 ],
#        [ 0.9823475 ],
#        [ 2.6570609 ],
#        [ 0.38309804],
#        [ 7.7121973 ],
#        [ 4.699725  ],
#        [ 3.6520307 ],
#        [ 5.325074  ],
#        [ 8.317487  ],
#        [ 4.938683  ],
#        [ 7.7121973 ],
#        [ 0.33702514],
#        [ 9.710944  ],
#        [ 0.9823475 ],
#        [ 9.425389  ],
#        [ 0.35007194],
#        [ 7.4706697 ],
#        [ 3.1671827 ],
#        [ 1.0948642 ],
#        [ 5.7700424 ],
#        [ 8.057833  ],
#        [ 1.4449164 ],
#        [ 4.5863166 ],
#        [ 4.89999   ],
#        [ 1.9272991 ],
#        [ 5.059063  ],
#        [ 0.8948339 ],
#        [ 0.33702514],
#        [ 9.01933   ],
#        [ 1.2115475 ],
#        [ 5.435397  ],
#        [11.626195  ],
#        [ 4.1022863 ],
#        [11.026906  ],
#        [ 9.152903  ],
#        [ 4.7796106 ],
#        [ 4.12531   ],
#        [ 9.217018  ],
#        [ 0.7823181 ],
#        [ 4.024582  ],
#        [ 0.4287827 ],
#        [ 4.3037415 ],
#        [ 0.95317566],
#        [ 9.01933   ],
#        [ 6.7252636 ],
#        [ 0.84065974],
#        [ 2.451409  ],
#        [ 3.0951319 ],
#        [ 5.8312907 ],
#        [10.526469  ],
#        [11.199897  ],
#        [ 7.7121973 ],
#        [ 0.3370252 ],
#        [ 5.5089455 ],
#        [ 2.7256866 ],
#        [11.36671   ],
#        [ 7.9578905 ],
#        [ 9.791261  ],
#        [ 7.283277  ],
#        [ 7.5206413 ],
#        [ 2.1000323 ],
#        [ 3.5385213 ],
#        [ 6.8626842 ],
#        [ 7.1416917 ],
#        [ 3.1671827 ],
#        [ 1.8589675 ],
#        [11.626195  ],
#        [ 9.286475  ],
#        [ 7.907919  ],
#        [ 8.752185  ],
#        [ 6.908492  ],
#        [ 0.81148857],
#        [11.026906  ],
#        [ 0.6739683 ],
#        [ 6.908492  ],
#        [ 8.317487  ],
#        [ 9.083445  ],
#        [ 1.5032574 ],
#        [ 3.4622998 ],
#        [ 9.01933   ],
#        [ 4.699725  ],
#        [ 0.7573137 ],
#        [ 2.7048006 ],
#        [ 9.710944  ],
#        [ 6.454585  ],
#        [ 3.5743904 ],
#        [ 8.495562  ],
#        [ 1.726859  ],
#        [ 8.559867  ],
#        [11.799185  ],
#        [ 7.762169  ],
#        [ 6.1407084 ],
#        [ 6.500392  ],
#        [ 1.6266396 ],
#        [ 7.762169  ],
#        [ 7.8121405 ],
#        [10.199023  ],
#        [ 0.61562675],
#        [ 3.2022488 ],
#        [ 6.679456  ],
#        [ 7.187498  ],
#        [ 7.424862  ],
#        [ 1.5657673 ],
#        [ 8.752185  ],
#        [ 0.8948339 ],
#        [ 9.01933   ],
#        [ 0.33702514],
#        [ 4.2548165 ],
#        [ 1.4449159 ],
#        [ 0.6989722 ],
#        [10.199023  ],
#        [ 5.3986235 ],
#        [ 1.2698901 ],
#        [ 0.3668973 ],
#        [ 0.7573137 ],
#        [ 0.32380292],
#        [ 4.076385  ],
#        [ 1.26989   ],
#        [10.27934   ],
#        [ 8.949872  ],
#        [ 4.5863166 ],
#        [ 7.762169  ],
#        [ 0.35007194],
#        [ 5.864541  ],
#        [ 0.35007194],
#        [ 9.286475  ],
#        [ 3.936818  ],
#        [ 6.8626842 ],
#        [ 8.885758  ],
#        [ 2.6093209 ],
#        [ 7.095885  ],
#        [ 8.057832  ],
#        [ 3.8941    ],
#        [ 6.633649  ],
#        [ 9.558962  ],
#        [11.539699  ],
#        [ 8.157776  ],
#        [ 1.0115185 ],
#        [ 7.5206413 ],
#        [ 4.001559  ],
#        [ 5.7332687 ],
#        [ 1.299061  ],
#        [ 2.2031024 ],
#        [ 8.207747  ],
#        [ 5.2923756 ],
#        [ 4.024582  ],
#        [ 4.076385  ],
#        [ 3.6900022 ],
#        [10.27934   ],
#        [ 5.128895  ],
#        [10.526469  ],
#        [ 2.451409  ],
#        [ 2.310858  ],
#        [10.693281  ],
#        [ 5.0877724 ],
#        [ 4.5107117 ],
#        [ 4.938683  ],
#        [11.539699  ],
#        [ 6.5461993 ],
#        [ 2.6809309 ],
#        [ 8.207747  ],
#        [10.359656  ],
#        [11.026906  ],
#        [ 4.001559  ],
#        [ 0.40769747],
#        [ 7.8579473 ],
#        [ 4.001559  ],
#        [ 0.9823475 ],
#        [ 0.5072768 ],
#        [ 9.217018  ],
#        [ 9.217018  ],
#        [ 3.770692  ],
#        [11.199897  ],
#        [10.27934   ],
#        [10.439974  ],
#        [10.439974  ],
#        [ 7.666391  ],
#        [ 9.425389  ],
#        [ 0.35007194],
#        [ 5.059063  ],
#        [ 3.9747899 ],
#        [ 5.8947673 ],
#        [10.112529  ],
#        [ 0.6989722 ],
#        [10.773601  ],
#        [ 7.424862  ],
#        [ 4.076385  ],
#        [ 1.1240349 ],
#        [10.940412  ],
#        [ 3.770692  ],
#        [ 2.4186141 ],
#        [ 3.273987  ],
#        [ 4.12531   ],
#        [ 0.35007194],
#        [10.359656  ],
#        [ 9.558962  ],
#        [ 9.217018  ],
#        [ 2.1703072 ],
#        [ 6.233843  ],
#        [ 6.7252636 ],
#        [ 8.207747  ],
#        [ 1.4449159 ],
#        [10.526469  ],
#        [ 2.9264138 ],
#        [ 6.908492  ],
#        [ 5.3986235 ],
#        [ 9.286475  ],
#        [ 9.425389  ],
#        [ 3.421947  ],
#        [ 8.752185  ],
#        [ 6.367135  ],
#        [ 9.217018  ],
#        [11.799186  ],
#        [ 9.871577  ],
#        [ 2.5444164 ],
#        [ 7.4706697 ],
#        [11.626195  ],
#        [ 2.7495568 ],
#        [ 5.964322  ],
#        [11.799185  ],
#        [ 0.47810602],
#        [ 2.8967516 ],
#        [ 4.177112  ],
#        [11.026906  ],
#        [ 3.770692  ],
#        [ 9.152903  ],
#        [11.36671   ],
#        [11.539699  ],
#        [ 2.1703072 ],
#        [ 6.500392  ],
#        [ 7.095885  ],
#        [ 2.6093209 ],
#        [10.112529  ],
#        [ 8.376845  ],
#        [ 6.587842  ],
#        [ 0.72814333],
#        [ 8.376845  ],
#        [10.27934   ],
#        [ 9.01933   ],
#        [ 8.157776  ],
#        [ 8.949872  ],
#        [ 2.310858  ],
#        [ 8.157776  ],
#        [ 5.1674433 ],
#        [11.199897  ],
#        [ 7.6663904 ],
#        [ 1.6949712 ],
#        [ 0.35007194],
#        [ 8.752185  ],
#        [ 4.001559  ],
#        [ 7.8121405 ],
#        [ 5.2923756 ],
#        [ 5.3986235 ],
#        [ 5.508946  ],
#        [ 0.3668973 ],
#        [ 0.33702514],
#        [ 6.8168774 ],
#        [ 1.0115185 ],
#        [ 7.907919  ],
#        [ 5.128895  ],
#        [ 9.489504  ],
#        [ 9.152903  ],
#        [11.113402  ],
#        [ 9.558962  ],
#        [ 6.367135  ],
#        [ 9.152903  ],
#        [ 9.083445  ],
#        [ 4.661922  ],
#        [ 6.408778  ],
#        [ 9.951894  ],
#        [ 3.5743906 ],
#        [ 5.8947678 ],
#        [ 9.01933   ],
#        [ 3.4981685 ],
#        [ 6.7710705 ],
#        [ 7.3748913 ],
#        [ 9.083445  ],
#        [ 2.7972968 ],
#        [10.526469  ],
#        [ 0.301136  ],
#        [ 4.8612967 ],
#        [ 8.317487  ],
#        [ 7.566448  ],
#        [ 0.5906225 ],
#        [ 2.5263698 ],
#        [11.626195  ],
#        [ 5.4721713 ],
#        [ 1.2407188 ],
#        [ 5.2267475 ],
#        [ 6.8168774 ],
#        [ 4.076385  ],
#        [ 3.3143394 ],
#        [ 3.6900022 ],
#        [ 6.8168774 ],
#        [10.439974  ],
#        [ 6.1407084 ],
#        [ 8.057832  ],
#        [ 7.907919  ],
#        [ 1.7587473 ],
#        [ 3.8941    ],
#        [ 6.408778  ],
#        [ 7.0459127 ],
#        [ 1.4740872 ],
#        [ 2.5884345 ],
#        [ 2.310858  ],
#        [10.439974  ],
#        [11.626195  ],
#        [ 7.4706697 ],
#        [ 0.95317614],
#        [ 4.861296  ],
#        [ 3.3143394 ],
#        [11.199897  ],
#        [ 7.283277  ],
#        [ 1.3574029 ],
#        [11.026906  ],
#        [ 0.4287827 ],
#        [ 4.699725  ],
#        [ 8.436204  ],
#        [ 9.286475  ],
#        [10.27934   ],
#        [ 7.762169  ],
#        [ 1.6266396 ],
#        [ 2.3436534 ],
#        [ 4.355544  ],
#        [ 3.8513815 ],
#        [ 6.500392  ],
#        [ 5.801064  ],
#        [ 4.8612967 ],
#        [ 0.7573137 ],
#        [ 0.301136  ],
#        [ 3.2022488 ],
#        [ 8.107804  ],
#        [ 5.1674433 ],
#        [ 7.7121973 ],
#        [ 8.495562  ],
#        [ 2.8689067 ],
#        [ 6.408778  ],
#        [ 0.61562675],
#        [ 1.726859  ],
#        [ 1.6585279 ],
#        [ 0.3668973 ],
#        [11.885681  ],
#        [10.773601  ],
#        [10.860093  ],
#        [ 1.5032574 ],
#        [ 3.3502085 ],
#        [ 4.2030134 ],
#        [11.626195  ],
#        [ 3.1671827 ],
#        [ 1.0948642 ],
#        [ 7.666391  ],
#        [11.885681  ],
#        [ 9.871577  ],
#        [ 6.367135  ],
#        [11.453204  ],
#        [ 4.2548165 ],
#        [11.799185  ],
#        [ 2.7256866 ],
#        [ 2.7972965 ],
#        [ 6.500392  ],
#        [ 9.489504  ],
#        [ 6.633649  ],
#        [ 2.3436534 ],
#        [ 9.871577  ],
#        [ 2.029756  ],
#        [ 7.329084  ],
#        [ 3.6102593 ],
#        [ 6.275521  ],
#        [ 9.355932  ],
#        [ 5.2267475 ],
#        [ 2.6570609 ],
#        [ 6.0919237 ],
#        [ 3.538521  ],
#        [ 2.993412  ],
#        [ 7.907919  ],
#        [ 4.1022863 ],
#        [ 9.630626  ],
#        [ 5.508946  ],
#        [ 9.286475  ],
#        [ 5.6192684 ],
#        [ 8.376845  ],
#        [ 0.86983085],
#        [ 4.2548165 ],
#        [ 2.7256866 ],
#        [ 4.472909  ],
#        [ 9.217018  ],
#        [ 4.2548165 ],
#        [ 8.681884  ],
#        [ 1.036522  ],
#        [10.526469  ],
#        [ 7.1416917 ],
#        [ 6.633649  ],
#        [ 6.633649  ],
#        [10.112529  ],
#        [ 5.2561474 ],
#        [ 7.283277  ],
#        [ 7.329084  ],
#        [11.026906  ],
#        [ 5.2267475 ],
#        [ 6.500392  ],
#        [ 8.949872  ],
#        [ 4.89999   ],
#        [ 5.23713   ],
#        [ 0.35007194],
#        [ 2.5645869 ],
#        [ 7.712198  ],
#        [ 7.8121405 ],
#        [ 4.355544  ],
#        [ 4.3931026 ],
#        [ 4.329643  ],
#        [ 3.5385213 ],
#        [ 8.376845  ],
#        [ 7.187498  ],
#        [ 0.33702514],
#        [ 5.2561474 ],
#        [ 9.558962  ],
#        [ 7.424862  ],
#        [ 7.8121405 ],
#        [ 1.3282318 ],
#        [ 0.38309804],
#        [ 8.681884  ],
#        [ 7.233306  ],
#        [ 8.885758  ],
#        [ 2.273378  ],
#        [ 8.157776  ],
#        [11.626195  ],
#        [ 8.317487  ],
#        [ 6.500392  ],
#        [ 5.656043  ],
#        [ 4.6241193 ],
#        [ 5.656043  ],
#        [ 5.54572   ],
#        [ 1.726859  ],
#        [ 3.0273187 ],
#        [10.032211  ],
#        [ 5.2561474 ],
#        [ 7.0958843 ],
#        [ 1.6585276 ],
#        [ 1.4449159 ],
#        [10.439974  ],
#        [ 5.361849  ],
#        [ 8.619225  ],
#        [ 9.489504  ],
#        [11.626195  ],
#        [ 5.059063  ],
#        [ 2.2405822 ],
#        [ 3.0612247 ],
#        [10.439974  ],
#        [ 6.587842  ],
#        [ 2.3436534 ],
#        [ 4.3037415 ],
#        [ 7.9578905 ],
#        [ 8.207747  ],
#        [ 2.7972965 ],
#        [ 4.8612967 ],
#        [ 4.699725  ],
#        [ 3.1332765 ],
#        [10.693281  ],
#        [ 9.152903  ],
#        [ 4.472909  ],
#        [ 4.699725  ],
#        [ 6.954299  ],
#        [ 2.6331909 ],
#        [ 0.32380292],
#        [ 6.679456  ],
#        [ 2.6093209 ],
#        [ 0.35007194],
#        [ 4.4309053 ],
#        [ 1.9272997 ],
#        [ 0.5364481 ],
#        [ 7.095885  ],
#        [ 6.454585  ],
#        [ 0.38309804],
#        [ 1.5365963 ],
#        [ 8.057832  ],
#        [ 5.7332687 ],
#        [ 6.5461993 ],
#        [11.885681  ],
#        [ 2.4888892 ],
#        [ 8.559867  ],
#        [ 5.656043  ],
#        [ 7.233306  ],
#        [ 4.6241193 ],
#        [ 9.01933   ],
#        [10.940412  ],
#        [ 0.7823181 ],
#        [ 6.679456  ],
#        [10.860093  ],
#        [11.799185  ],
#        [ 2.8689067 ],
#        [10.693281  ],
#        [ 9.286475  ],
#        [ 3.3860776 ],
#        [ 6.321328  ],
#        [11.026906  ],
#        [ 7.566448  ],
#        [ 1.959481  ],
#        [ 4.938683  ],
#        [ 5.059063  ],
#        [ 2.451409  ],
#        [ 4.4729085 ],
#        [ 0.35007164],
#        [ 4.818304  ],
#        [ 5.582494  ],
#        [ 5.435397  ],
#        [10.693281  ],
#        [ 9.791261  ],
#        [ 5.801064  ],
#        [ 4.6241193 ],
#        [11.36671   ],
#        [11.026906  ],
#        [ 1.6949712 ],
#        [ 7.8121405 ],
#        [ 5.924995  ],
#        [10.27934   ],
#        [ 4.280718  ],
#        [11.799185  ],
#        [ 8.949872  ],
#        [ 0.61562675],
#        [ 8.949872  ],
#        [ 9.871577  ],
#        [10.693281  ],
#        [ 3.0273187 ],
#        [ 7.8579473 ],
#        [11.799185  ],
#        [ 5.133991  ],
#        [ 6.367135  ],
#        [ 7.5206413 ],
#        [ 4.5863166 ],
#        [ 0.86983085],
#        [ 9.286475  ],
#        [11.199897  ],
#        [10.7736    ],
#        [ 8.885758  ],
#        [ 7.8579473 ],
#        [ 7.5206413 ],
#        [11.453204  ],
#        [ 5.4721713 ],
#        [ 3.3143394 ],
#        [ 1.9922757 ],
#        [ 6.954299  ],
#        [ 8.436204  ],
#        [ 0.61562675],
#        [ 8.559867  ],
#        [11.453204  ],
#        [ 5.128895  ],
#        [ 5.2561474 ],
#        [ 3.7327206 ],
#        [11.626195  ],
#        [ 9.425389  ],
#        [ 5.656043  ],
#        [10.526469  ],
#        [ 3.770692  ],
#        [ 2.5645869 ],
#        [ 4.6241193 ],
#        [ 6.0519257 ],
#        [ 0.4287827 ],
#        [ 0.5906225 ],
#        [ 6.633649  ],
#        [ 1.2115475 ],
#        [ 2.821167  ],
#        [ 7.8121405 ],
#        [ 7.4706697 ],
#        [ 5.2561474 ],
#        [11.199897  ],
#        [ 3.386078  ],
#        [ 6.954299  ],
#        [11.712689  ],
#        [ 2.7972965 ],
#        [11.539699  ],
#        [ 3.6102593 ],
#        [ 4.076385  ],
#        [ 5.1100006 ],
#        [ 5.924995  ],
#        [ 2.7734268 ],
#        [10.359656  ],
#        [ 9.630626  ],
#        [11.539699  ],
#        [ 3.936818  ],
#        [ 9.710944  ],
#        [ 6.321328  ],
#        [ 2.4888892 ],
#        [11.885681  ],
#        [ 7.000106  ],
#        [ 8.317487  ],
#        [ 0.61562675],
#        [10.112529  ],
#        [ 2.310858  ],
#        [ 3.0612247 ],
#        [ 9.558962  ],
#        [ 3.6520307 ],
#        [ 7.000106  ],
#        [ 0.47810602],
#        [ 9.217018  ],
#        [ 2.7256866 ],
#        [ 7.9578905 ],
#        [ 3.81341   ],
#        [10.199023  ],
#        [ 0.301136  ],
#        [ 3.8941    ],
#        [ 0.8948339 ],
#        [ 4.661922  ],
#        [ 2.5444164 ],
#        [ 9.217018  ],
#        [ 8.752185  ],
#        [ 1.0656929 ],
#        [ 8.559867  ],
#        [ 9.871577  ],
#        [ 5.864541  ],
#        [ 5.1674433 ],
#        [ 0.31246963],
#        [ 1.8270792 ],
#        [ 9.558962  ],
#        [11.539699  ],
#        [11.026906  ],
#        [ 7.666391  ],
#        [ 6.500392  ],
#        [ 5.059063  ],
#        [ 1.3574029 ],
#        [ 8.681884  ],
#        [ 9.630626  ],
#        [ 0.9823475 ],
#        [11.453204  ],
#        [ 2.451409  ],
#        [ 0.5072768 ],
#        [ 5.231498  ],
#        [ 5.2267475 ],
#        [ 3.3502085 ],
#        [ 6.0519257 ],
#        [ 6.454585  ],
#        [11.885681  ],
#        [ 6.367135  ],
#        [ 1.6949712 ],
#        [ 0.86983085],
#        [ 8.8163    ],
#        [ 6.1850586 ],
#        [ 2.5645869 ],
#        [ 5.231498  ],
#        [ 3.7327206 ],
#        [10.359656  ],
#        [ 4.699725  ],
#        [ 6.0919237 ],
#        [ 2.3436534 ],
#        [ 5.924995  ],
#        [ 0.5364479 ],
#        [ 6.0519257 ],
#        [10.693281  ],
#        [ 9.871577  ],
#        [ 0.3668973 ],
#        [ 5.4721713 ],
#        [ 4.228915  ],
#        [ 6.233843  ],
#        [10.439974  ],
#        [11.453204  ],
#        [ 2.8450365 ],
#        [ 2.029756  ],
#        [ 2.8967516 ],
#        [ 0.4287827 ],
#        [ 0.33702514],
#        [ 0.9823475 ],
#        [11.626195  ],
#        [ 7.6663904 ],
#        [11.36671   ]], dtype=float32)

# %%
X_test[0]
# Out:
# array([0.52163185])

# %%
arr = X_test
X_test0 = arr[:1]
X_test0
# Out:
# array([[0.52163185]])

# %%
valid_predictions_df=pd.DataFrame(valid_predictions)
valid_predictions_df.columns = ["valid_displacement"]
valid_predictions_df
# Out:
#      valid_displacement
# 0              7.095885
# 1             10.606788
# 2              9.019330
# 3             11.799185
# 4              3.202249
# ..                  ...
# 764            0.337025
# 765            0.982347
# 766           11.626195
# 767            7.666390
# 768           11.366710
#
# [769 rows x 1 columns]

# %%
k= y_valid.to_numpy()
k_df = pd.DataFrame(k)
k_df.columns  = ["displacement"]
k_df
# Out:
#      displacement
# 0            6.74
# 1           11.09
# 2            8.73
# 3           12.01
# 4            3.39
# ..            ...
# 764          0.00
# 765          0.67
# 766         11.82
# 767          8.40
# 768         11.76
#
# [769 rows x 1 columns]

# %%
k_df.describe()
# Out:
#        displacement
# count    769.000000
# mean       5.855787
# std        3.609648
# min        0.000000
# 25%        2.820000
# 50%        5.770000
# 75%        8.920000
# max       12.010000

# %%
ValidPre = pd.concat( [k_df,valid_predictions_df],axis=1)
ValidPre.head(5)
corr = ValidPre.corr()
print("corr")
for i in range(0,1):    
    print(format(corr[valid_predictions_df.columns[i]][k_df.columns[i]]*100,'.2f')+'%',k_df.columns[i])
corr
# Out:
# corr
# 99.65% displacement
#                     displacement  valid_displacement
# displacement            1.000000            0.996501
# valid_displacement      0.996501            1.000000

# %%
alpa=0.1

ValidPre.plot(kind="scatter", x= "valid_displacement",y= "displacement",alpha = alpa)
#plt.savefig('D:/ME program/2017-PhD/01_research/02Study/34_ballon_like_cover/DeepLearing/SensorCallbi/LABS_v3/savefig/210903_70ms_3ea_sin.png')
# Out:
# <Axes: xlabel='valid_displacement', ylabel='displacement'>
